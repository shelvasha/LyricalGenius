# %% [markdown]
# # Horrorwave Classifier

# %%
### Decision Tree
import pandas as pd
import numpy as np

import sklearn as tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

# from sklearn.tree import export_graphviz
# import pydotplus
# import io
# from scipy import misc

# %matplotlib inline

# %% [markdown]
# ## Spotify Song Attributes EDA
# - Import Dataset
# - EDA to visualize and observe structure
# - Train classifier (Decision Tree)
# - Predict Target (Does an out side playlist contain music that fits the model?)
# - NOTE: The feature of 'top genre' was used as a discriminator of ideal sound aestethic of horrorsynth tracks. This tag was sgise based on popularity of use. Here, 'darksynth', 'dark clubbing' and 'synthwave' represent desired parameters.

# %%
data = pd.read_csv('horrorwave.csv') # Training data

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#               year         bpm        nrgy        dnce          dB  \
# count   101.000000  101.000000  101.000000  101.000000  101.000000
# mean   2019.227723  125.584158   83.336634   50.306931   -6.821782
# std       1.455206   21.063365   12.166575    9.236604    2.861454
# min    2016.000000   70.000000   56.000000   22.000000  -14.000000
# 25%    2018.000000  115.000000   74.000000   45.000000   -9.000000
# 50%    2020.000000  128.000000   87.000000   50.000000   -7.000000
# 75%    2020.000000  135.000000   93.000000   57.000000   -5.000000
# max    2021.000000  180.000000  100.000000   68.000000    0.000000
#
#              live         val         dur       acous        spch         pop  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean    20.821782   23.217822  246.881188    1.663366    7.336634   15.831683
# std     15.743822   17.331823   50.685755    6.323412    6.456434    9.513222
# ...

# %%
data.head()
# Out:
#                   title          artist  top genre  year       added  bpm  \
# 0  Dose (Grendel Remix)         Ophelia  aggrotech  2021  2021‑02‑10  120
# 1    Destroy All Humans  Deadly Avenger   big beat  2019  2020‑01‑22  110
# 2      The Cult of 2112     Perturbator  cyberpunk  2016  2019‑12‑25  140
# 3   Upgraded Resistance  We Are Magonia  cyberpunk  2020  2020‑12‑03  125
# 4        Slaughterhouse  We Are Magonia  cyberpunk  2019  2020‑12‑04  148
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop  target
# 0    95    68 -10     9   62  280      0     4   16       0
# 1    93    62 -10    54   55  227     27     6    0       0
# 2   100    49   0    36   13  238      0    37   36       0
# 3    67    37  -8     7   17  270      0     8   31       0
# 4    88    42  -8     9   18  251      0    15   27       0

# %%
data['top genre'].unique(), data['top genre'].value_counts()
# Out:
# (array(['aggrotech', 'big beat', 'cyberpunk', 'dark clubbing', 'darksynth',
#         'filthstep', 'french hardcore', 'horror synth', 'synthwave',
#         'synthwave brasileiro', nan], dtype=object),
#  dark clubbing           26
#  cyberpunk               15
#  darksynth               10
#  synthwave                6
#  synthwave brasileiro     2
#  big beat                 1
#  filthstep                1
#  french hardcore          1
#  horror synth             1
#  aggrotech                1
#  Name: top genre, dtype: int64)

# %% [markdown]
# ## Graphs

# %%
# lbl_1 = data[data['target'] == 1]['bpm']
# lbl_2 = data[data['target'] == 1]['nrgy']
# fig = plt.figure(figsize=(12,8))
# plt.title('BPM Horror vs. non-Horror Synthwave')
# plt.scatter(lbl_1,lbl_2)

data.groupby('target').size().plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pos_nrgy = data[data['target'] == 1]['nrgy']
neg_nrgy = data[data['target'] == 0]['nrgy']

fig = plt.figure(figsize=(12,8))
plt.title('Energy Horror vs non-Horror Synthwave')

pos_nrgy.hist(alpha = 0.7, bins = 10, label = 'positive')
neg_nrgy.hist(alpha = 0.7, bins = 10, label = 'negative')

plt.legend(loc='upper right')

# %% [markdown]
# ## Training Our Data

# %%
train, test = train_test_split(data, test_size = 0.15)

# %%
print ("Training set size: {}; Text size: {}".format(len(train), len(test)))
# Out:
# Training set size: 85; Text size: 16

# %% [markdown]
# ### Features

# %%
features = ['bpm','nrgy','dnce','dB','live','val','dur','acous','spch','pop','target']

# %%
c = DecisionTreeClassifier(min_samples_split=50)

# %%
X_train = train[features]
y_train = train['target']

X_test = test[features]
y_test = test['target']

# %%
dt = c.fit(X_train, y_train)
